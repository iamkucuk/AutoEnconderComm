# %%
from keras.layers import Input, Dense, GaussianNoise, Lambda, Dropout, concatenate, LSTM
from keras.models import Model, Sequential, load_model
from keras import regularizers
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, SGD
from keras import backend as K
import numpy as np
import keras
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from keras.utils import plot_model
from datetime import datetime
import matplotlib.pyplot as plt
import tensorflow as tf
import random

seed_number = 20
tf.set_random_seed(seed_number)
random.seed(seed_number)
np.random.seed(seed_number)
# Out:
# Using TensorFlow backend.

# %%
SNR1 = 10
SNR2 = 10

# %%
k = 2
M = 2 ** k
k = int(k)
n_channel = 2
R = k / n_channel
calc_ebno = lambda SNR: 10 ** (SNR / 10)
ebno1 = calc_ebno(SNR1)
ebno2 = calc_ebno(SNR2)

# %%
def generate_data(M, N=100000, n_receiver=2):
    label = np.random.randint(M, size=N)

    data = np.zeros((N, M))
    for i in range(N):
        data[i, label[i]] = 1
    np.random.shuffle(data)
    return data

# %%
# Layer definitions
input_signal1 = Input(shape=(M,), name="input1")
input_signal2 = Input(shape=(M,), name="input2")
encoder1 = Sequential([
    Dense(M, activation="relu"),
    Dense(n_channel, activation="linear")
], name="encoder1")
encoder2 = Sequential([
    Dense(M, activation="relu"),
    Dense(n_channel, activation="linear")
], name="encoder2")

combiner = Sequential([
    Dense(n_channel, activation="relu"),
    Dense(n_channel, activation="linear"),
    # Lambda(lambda x: np.sqrt(n_channel)*K.l2_normalize(x,axis=1), name="normalization")
    BatchNormalization(center=False, scale=False)
], name="combiner")

signal_input1 = GaussianNoise(np.sqrt(1 / (2 * R * ebno1)))
signal_input2 = GaussianNoise(np.sqrt(1 / (2 * R * ebno2)))

decoder1 = Sequential([
    Dense(M, activation="relu"),
    Dense(M, activation="softmax")
], name="decoder1")
decoder2 = Sequential([
    Dense(M, activation="relu"),
    Dense(M, activation="softmax")
], name="decoder2")

# %%
# Computation graph
x1 = encoder1(input_signal1)
x2 = encoder2(input_signal2)
x = concatenate([x1, x2], axis=1)
x = combiner(x)
x1 = signal_input1(x)
x2 = signal_input2(x)
out1 = decoder1(x1)
out2 = decoder2(x2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model = Model(inputs=[input_signal1, input_signal2], outputs=[out1, out2])
model.summary()
alpha = K.variable(.5)

model.compile(optimizer="adam", loss=["categorical_crossentropy", "categorical_crossentropy"],
              loss_weights=[alpha, (1 - alpha)], metrics=["accuracy"])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input1 (InputLayer)             (None, 4)            0
# __________________________________________________________________________________________________
# input2 (InputLayer)             (None, 4)            0
# __________________________________________________________________________________________________
# encoder1 (Sequential)           (None, 2)            30          input1[0][0]
# __________________________________________________________________________________________________
# encoder2 (Sequential)           (None, 2)            30          input2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4)            0           encoder1[1][0]
#                                                                  encoder2[1][0]
# __________________________________________________________________________________________________
# combiner (Sequential)           (None, 2)            20          concatenate_1[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 2)            0           combiner[1][0]
# __________________________________________________________________________________________________
# gaussian_noise_2 (GaussianNoise (None, 2)            0           combiner[1][0]
# __________________________________________________________________________________________________
# decoder1 (Sequential)           (None, 4)            32          gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# decoder2 (Sequential)           (None, 4)            32          gaussian_noise_2[0][0]
# ==================================================================================================
# Total params: 144
# Trainable params: 140
# Non-trainable params: 4
# __________________________________________________________________________________________________

# %%
plot_model(model, "hebe.png")

# %%
logdir = "logs/scalars/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=logdir)
early_stop = EarlyStopping(patience=100, restore_best_weights=True, monitor="loss")
# ckpt_callback = ModelCheckpoint(filepath="checkpoints/weights.{epoch:02d}-{val_loss:.2f}.hdf5", monitor="val_loss")
ckpt_callback = ModelCheckpoint(filepath="checkpoints/weights.hdf5", monitor="val_loss")

# %%
class AlphaCallback(Callback):
    def __init__(self, alpha):
        super().__init__()
        self.alpha = alpha

    def on_batch_end(self, batch, logs=None):
        loss1, loss2 = logs["decoder1_loss"], logs["decoder2_loss"]
        K.set_value(self.alpha, loss1 / (loss1 + loss2))
        # self.alpha = loss1 / (loss1 + loss2)

# %%
train_data_1 = generate_data(M, N=40000)
train_data_2 = generate_data(M, N=40000)

# %%
model.fit(x=[train_data_1, train_data_2], y=[train_data_1, train_data_2], validation_split=.5, batch_size=1024,
          epochs=2000, callbacks=[
        tensorboard_callback,
        early_stop,
        # ckpt_callback,
        ReduceLROnPlateau(monitor="loss", factor=.1, patience=20),
        # SGDRScheduler(min_lr=1e-5, max_lr=1e-1, steps_per_epoch=np.ceil(train_data_1.shape[0]/1024)),
        AlphaCallback(alpha)
    ])
# Out:
# r2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 345/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0974 - decoder1_loss: 0.1008 - decoder2_loss: 0.0929 - decoder1_accuracy: 0.9632 - decoder2_accuracy: 0.9658 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 346/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0990 - decoder1_loss: 0.1036 - decoder2_loss: 0.0930 - decoder1_accuracy: 0.9632 - decoder2_accuracy: 0.9663 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 347/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0974 - decoder1_loss: 0.0988 - decoder2_loss: 0.0971 - decoder1_accuracy: 0.9654 - decoder2_accuracy: 0.9643 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 348/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0945 - decoder1_loss: 0.0948 - decoder2_loss: 0.0943 - decoder1_accuracy: 0.9666 - decoder2_accuracy: 0.9657 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 349/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0968 - decoder1_loss: 0.0964 - decoder2_loss: 0.0969 - decoder1_accuracy: 0.9655 - decoder2_accuracy: 0.9640 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 350/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0965 - decoder1_loss: 0.1001 - decoder2_loss: 0.0936 - decoder1_accuracy: 0.9638 - decoder2_accuracy: 0.9645 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 351/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0952 - decoder1_loss: 0.0989 - decoder2_loss: 0.0917 - decoder1_accuracy: 0.9650 - decoder2_accuracy: 0.9671 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 352/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0949 - decoder1_loss: 0.0968 - decoder2_loss: 0.0938 - decoder1_accuracy: 0.9667 - decoder2_accuracy: 0.9641 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 353/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0974 - decoder1_loss: 0.1017 - decoder2_loss: 0.0926 - decoder1_accuracy: 0.9630 - decoder2_accuracy: 0.9663 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 354/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0942 - decoder1_loss: 0.0975 - decoder2_loss: 0.0899 - decoder1_accuracy: 0.9638 - decoder2_accuracy: 0.9681 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 355/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0929 - decoder1_loss: 0.0955 - decoder2_loss: 0.0904 - decoder1_accuracy: 0.9649 - decoder2_accuracy: 0.9675 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 356/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0974 - decoder1_loss: 0.0976 - decoder2_loss: 0.0984 - decoder1_accuracy: 0.9658 - decoder2_accuracy: 0.9647 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 357/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0978 - decoder1_loss: 0.1015 - decoder2_loss: 0.0946 - decoder1_accuracy: 0.9638 - decoder2_accuracy: 0.9641 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 358/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0960 - decoder1_loss: 0.0990 - decoder2_loss: 0.0927 - decoder1_accuracy: 0.9649 - decoder2_accuracy: 0.9651 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 359/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0954 - decoder1_loss: 0.0998 - decoder2_loss: 0.0919 - decoder1_accuracy: 0.9639 - decoder2_accuracy: 0.9678 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 360/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0946 - decoder1_loss: 0.0956 - decoder2_loss: 0.0939 - decoder1_accuracy: 0.9668 - decoder2_accuracy: 0.9664 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 361/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0950 - decoder1_loss: 0.0973 - decoder2_loss: 0.0924 - decoder1_accuracy: 0.9647 - decoder2_accuracy: 0.9656 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 362/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0969 - decoder1_loss: 0.0971 - decoder2_loss: 0.0970 - decoder1_accuracy: 0.9651 - decoder2_accuracy: 0.9636 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 363/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0954 - decoder1_loss: 0.0953 - decoder2_loss: 0.0954 - decoder1_accuracy: 0.9685 - decoder2_accuracy: 0.9644 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 364/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0968 - decoder1_loss: 0.1002 - decoder2_loss: 0.0941 - decoder1_accuracy: 0.9642 - decoder2_accuracy: 0.9654 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 365/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0927 - decoder1_loss: 0.0924 - decoder2_loss: 0.0928 - decoder1_accuracy: 0.9670 - decoder2_accuracy: 0.9659 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 366/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0981 - decoder1_loss: 0.0989 - decoder2_loss: 0.0969 - decoder1_accuracy: 0.9636 - decoder2_accuracy: 0.9647 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 367/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0971 - decoder1_loss: 0.0977 - decoder2_loss: 0.0965 - decoder1_accuracy: 0.9665 - decoder2_accuracy: 0.9632 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 368/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0965 - decoder1_loss: 0.0989 - decoder2_loss: 0.0946 - decoder1_accuracy: 0.9636 - decoder2_accuracy: 0.9651 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 369/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0939 - decoder1_loss: 0.0981 - decoder2_loss: 0.0885 - decoder1_accuracy: 0.9646 - decoder2_accuracy: 0.9675 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 370/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0979 - decoder1_loss: 0.1017 - decoder2_loss: 0.0939 - decoder1_accuracy: 0.9636 - decoder2_accuracy: 0.9649 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 371/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0965 - decoder1_loss: 0.0978 - decoder2_loss: 0.0950 - decoder1_accuracy: 0.9660 - decoder2_accuracy: 0.9647 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 372/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0980 - decoder1_loss: 0.0967 - decoder2_loss: 0.1001 - decoder1_accuracy: 0.9669 - decoder2_accuracy: 0.9643 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 373/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0961 - decoder1_loss: 0.0981 - decoder2_loss: 0.0939 - decoder1_accuracy: 0.9655 - decoder2_accuracy: 0.9663 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 374/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0938 - decoder1_loss: 0.0979 - decoder2_loss: 0.0905 - decoder1_accuracy: 0.9653 - decoder2_accuracy: 0.9671 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 375/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0951 - decoder1_loss: 0.0995 - decoder2_loss: 0.0899 - decoder1_accuracy: 0.9643 - decoder2_accuracy: 0.9671 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 376/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.1000 - decoder1_loss: 0.1007 - decoder2_loss: 0.0989 - decoder1_accuracy: 0.9645 - decoder2_accuracy: 0.9625 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 377/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0971 - decoder1_loss: 0.1011 - decoder2_loss: 0.0934 - decoder1_accuracy: 0.9645 - decoder2_accuracy: 0.9663 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 378/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0930 - decoder1_loss: 0.0947 - decoder2_loss: 0.0921 - decoder1_accuracy: 0.9665 - decoder2_accuracy: 0.9671 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 379/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0960 - decoder1_loss: 0.0969 - decoder2_loss: 0.0954 - decoder1_accuracy: 0.9649 - decoder2_accuracy: 0.9644 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 380/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0952 - decoder1_loss: 0.0980 - decoder2_loss: 0.0924 - decoder1_accuracy: 0.9646 - decoder2_accuracy: 0.9660 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 381/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0976 - decoder1_loss: 0.1003 - decoder2_loss: 0.0946 - decoder1_accuracy: 0.9637 - decoder2_accuracy: 0.9670 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 382/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0962 - decoder1_loss: 0.0954 - decoder2_loss: 0.0964 - decoder1_accuracy: 0.9662 - decoder2_accuracy: 0.9648 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 383/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.1001 - decoder1_loss: 0.0995 - decoder2_loss: 0.1000 - decoder1_accuracy: 0.9628 - decoder2_accuracy: 0.9636 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 384/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0952 - decoder1_loss: 0.0974 - decoder2_loss: 0.0930 - decoder1_accuracy: 0.9657 - decoder2_accuracy: 0.9657 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 385/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0978 - decoder1_loss: 0.1031 - decoder2_loss: 0.0927 - decoder1_accuracy: 0.9637 - decoder2_accuracy: 0.9644 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 386/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0924 - decoder1_loss: 0.0929 - decoder2_loss: 0.0929 - decoder1_accuracy: 0.9685 - decoder2_accuracy: 0.9660 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 387/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0936 - decoder1_loss: 0.0990 - decoder2_loss: 0.0882 - decoder1_accuracy: 0.9644 - decoder2_accuracy: 0.9686 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 388/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0957 - decoder1_loss: 0.0977 - decoder2_loss: 0.0928 - decoder1_accuracy: 0.9658 - decoder2_accuracy: 0.9653 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 389/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0975 - decoder1_loss: 0.1019 - decoder2_loss: 0.0942 - decoder1_accuracy: 0.9639 - decoder2_accuracy: 0.9657 - val_loss: 0.0034 - val_decoder1_loss: 0.0042 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 390/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0977 - decoder1_loss: 0.1008 - decoder2_loss: 0.0949 - decoder1_accuracy: 0.9647 - decoder2_accuracy: 0.9648 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 391/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0951 - decoder1_loss: 0.0969 - decoder2_loss: 0.0943 - decoder1_accuracy: 0.9670 - decoder2_accuracy: 0.9661 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 392/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0977 - decoder1_loss: 0.1016 - decoder2_loss: 0.0940 - decoder1_accuracy: 0.9640 - decoder2_accuracy: 0.9651 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 393/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0928 - decoder1_loss: 0.0968 - decoder2_loss: 0.0874 - decoder1_accuracy: 0.9639 - decoder2_accuracy: 0.9674 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 394/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0954 - decoder1_loss: 0.0992 - decoder2_loss: 0.0906 - decoder1_accuracy: 0.9647 - decoder2_accuracy: 0.9669 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 395/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0981 - decoder1_loss: 0.1013 - decoder2_loss: 0.0945 - decoder1_accuracy: 0.9652 - decoder2_accuracy: 0.9662 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 396/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0971 - decoder1_loss: 0.0994 - decoder2_loss: 0.0949 - decoder1_accuracy: 0.9641 - decoder2_accuracy: 0.9651 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 397/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0989 - decoder1_loss: 0.1029 - decoder2_loss: 0.0946 - decoder1_accuracy: 0.9641 - decoder2_accuracy: 0.9663 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 398/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0963 - decoder1_loss: 0.0984 - decoder2_loss: 0.0944 - decoder1_accuracy: 0.9662 - decoder2_accuracy: 0.9660 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 399/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0942 - decoder1_loss: 0.0966 - decoder2_loss: 0.0922 - decoder1_accuracy: 0.9647 - decoder2_accuracy: 0.9653 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 400/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0992 - decoder1_loss: 0.1015 - decoder2_loss: 0.0968 - decoder1_accuracy: 0.9650 - decoder2_accuracy: 0.9639 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 401/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0981 - decoder1_loss: 0.0984 - decoder2_loss: 0.0976 - decoder1_accuracy: 0.9640 - decoder2_accuracy: 0.9633 - val_loss: 0.0033 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 402/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0972 - decoder1_loss: 0.1000 - decoder2_loss: 0.0936 - decoder1_accuracy: 0.9635 - decoder2_accuracy: 0.9658 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 403/2000
# 20000/20000 [==============================] - 0s 4us/step - loss: 0.0966 - decoder1_loss: 0.0990 - decoder2_loss: 0.0947 - decoder1_accuracy: 0.9647 - decoder2_accuracy: 0.9649 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000
# Epoch 404/2000
# 20000/20000 [==============================] - 0s 3us/step - loss: 0.0965 - decoder1_loss: 0.0985 - decoder2_loss: 0.0940 - decoder1_accuracy: 0.9650 - decoder2_accuracy: 0.9661 - val_loss: 0.0034 - val_decoder1_loss: 0.0043 - val_decoder2_loss: 0.0024 - val_decoder1_accuracy: 1.0000 - val_decoder2_accuracy: 1.0000

# %%
scatter_plot = []
for i in range(M):
    temp = np.zeros(M)
    temp[i] = 1
    out1 = encoder1.predict(np.expand_dims(temp, axis=0))
    for j in range(M):
        temp2 = np.zeros(M)
        temp2[j] = 1
        out2 = encoder2.predict(np.expand_dims(temp2, axis=0))
        out = np.concatenate([out1.squeeze(0), out2.squeeze(0)])
        out = combiner.predict(np.expand_dims(out, axis=0))
        scatter_plot.append(out.squeeze(0))

scatter_plot = np.array(scatter_plot)

scatter_plot = scatter_plot.reshape(-1, 2, 1)

import matplotlib.pyplot as plt

plt.scatter(scatter_plot[:, 0], scatter_plot[:, 1])
# # plt.axis((-1,1,-1,1))
plt.grid()
plt.show()

# %%
# %%
SNR_range = np.arange(0, 21, 1)
ebno_range1 = calc_ebno(SNR_range)
ebno_range2 = calc_ebno(SNR_range - 6)
ber1, ber2 = [], []
test_data_1 = generate_data(M=M)
test_data_2 = generate_data(M=M)
for i in range(len(SNR_range)):
    ebno1 = ebno_range1[i]
    ebno2 = ebno_range2[i]
    out1 = encoder1.predict(test_data_1)
    out2 = encoder2.predict(test_data_2)
    concatenated = np.concatenate([out1, out2], axis=1)
    out = combiner.predict(concatenated)
    noise1 = np.sqrt(1 / (2 * R * ebno1)) * np.random.randn(*out.shape)
    noise2 = np.sqrt(1 / (2 * R * ebno2)) * np.random.randn(*out.shape)
    out1 = decoder1.predict(out + noise1)
    out2 = decoder2.predict(out + noise2)

    pred1 = np.argmax(out1, axis=1)
    pred2 = np.argmax(out2, axis=1)

    errors1 = np.asarray((pred1 != np.argmax(test_data_1, axis=1))).astype(int).mean()
    errors2 = np.asarray((pred2 != np.argmax(test_data_2, axis=1))).astype(int).mean()

    ber1.append(errors1)
    ber2.append(errors2)

print(ber1)
print(ber2)

plt.scatter(SNR_range, ber1)
plt.scatter(SNR_range, ber2)
plt.yscale("log")
plt.xlim((0, 20))
plt.show()
# Out:
# [0.39373, 0.35518, 0.31559, 0.27655, 0.23283, 0.19146, 0.15184, 0.11635, 0.0811, 0.05321, 0.03351, 0.01769, 0.00852, 0.00374, 0.00106, 0.00028, 3e-05, 0.0, 0.0, 0.0, 0.0]
# [0.55723, 0.53902, 0.51195, 0.48584, 0.45753, 0.4252, 0.3911, 0.35299, 0.31543, 0.27337, 0.23124, 0.19026, 0.14938, 0.11415, 0.07914, 0.05369, 0.03144, 0.01691, 0.00773, 0.00322, 0.00107]

# %%
plt.scatter(SNR_range, ber1)
plt.scatter(SNR_range, ber2)
plt.yscale("log")
plt.xlim((0, 20))
plt.grid()
plt.legend(["Higher", "Lower"])
plt.show()
